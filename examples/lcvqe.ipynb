# %%
import numpy as np
from sklearn.datasets import make_blobs
import plotly.express as px

import logging
import sys

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(sys.stdout)
    ]
)

COLORS = [
    "#f7dc6f",
    "#82e0aa",
    "#f1948a",
    "#499cef",
    "#f5b041",
    "#a569bd",
    "#e74c3c",
    "#2ecc71",
    "#3498db",
    "#e67e22",
    "#9b59b6",
    "#1abc9c",
    "#34495e",
    "#d35400",
    "#c0392b",
    "#16a085",
    "#2980b9",
    "#8e44ad",
]

def twospirals(n_points, noise=.5):
    n = np.sqrt(np.random.rand(n_points,1)) * 780 * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(n_points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(n_points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), np.hstack((np.zeros(n_points, dtype=int),np.ones(n_points, dtype=int))))

def plot_dataframe(df, title='', x='x', y='y', label='label'):
    df[label] = df[label].map(lambda x: str(x))
    fig = px.scatter(
        df.sort_values(by=label), 
        x=x, 
        y=y,
        color=label,
        color_discrete_map={str(i): COLORS[i] for i in range(len(COLORS))},
        title=title,
    )
    fig.update_traces(marker=dict(size=5, symbol='circle', opacity = 0.6))

    return fig

def plot_centroid(fig, centroid, colors = ['#a569bd'], marker_size=10, symbol = 'star', name = 'Centroid'):
    fig.add_scatter(
        x=[centroid[0]], 
        y=[centroid[1]], 
        mode='markers',
        marker=dict(
            size = marker_size,
            color = colors,
            symbol = symbol,
        ), 
        name=name
    )
    return fig

def create_constraints(labels, probability=0.01, seed=0):
    n_points = len(labels)
    constraints = np.zeros((n_points, n_points), dtype=int)
    state = np.random.RandomState(seed=seed)
    for i in range(n_points):
        for j in range(i +1, n_points):
            if state.rand() < probability:
                if labels[i] == labels[j]:
                    constraints[i, j] = 1
                    constraints[j, i] = 1
                elif labels[i] != labels[j]:
                    constraints[i, j] = -1
                    constraints[j, i] = -1
    return constraints

def draw_cl_constraints(fig, constraints, points):
    n_points = len(points)
    for i in range(n_points):
        for j in range(i + 1, n_points):
            if constraints[i, j] < 0:
                fig.add_scatter(
                    x=[points[i, 0], points[j, 0]], 
                    y=[points[i, 1], points[j, 1]], 
                    mode='lines',
                    line=dict(color='red', width=0.5, dash='dash'),
                )
    return fig

def draw_ml_constraints(fig, constraints, points):
    n_points = len(points)
    for i in range(n_points):
        for j in range(i + 1, n_points):
            if constraints[i, j] > 0:
                fig.add_scatter(
                    x=[points[i, 0], points[j, 0]], 
                    y=[points[i, 1], points[j, 1]], 
                    mode='lines',
                    line=dict(color='green', width=0.5),
                )
    return fig

# %%
X, y = make_blobs(n_samples=300, centers=10, cluster_std=1.0, random_state=42)
constraints = create_constraints(y, probability=0.01, seed=42)

# %%
from clustlib.fuzzy.lcvqe import LCVQE

lcvqe = LCVQE(
    n_clusters=10,
    constraints=constraints,
    max_iter=100,
    tol=1e-4
)
lcvqe.fit(X)
# Out:
# 2025-07-10 09:54:57,119 - DEBUG - Fitting LCVQE model
# 2025-07-10 09:54:57,121 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,122 - DEBUG - Iteration 0: Checking constraints
# 2025-07-10 09:54:57,150 - DEBUG - Iteration 0: Updating centroids
# 2025-07-10 09:54:57,166 - DEBUG - Iteration 0: Updating labels
# 2025-07-10 09:54:57,167 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,167 - DEBUG - Iteration 1: Checking constraints
# 2025-07-10 09:54:57,181 - DEBUG - Iteration 1: Updating centroids
# 2025-07-10 09:54:57,182 - DEBUG - Iteration 1: Updating labels
# 2025-07-10 09:54:57,183 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,183 - DEBUG - Iteration 2: Checking constraints
# 2025-07-10 09:54:57,193 - DEBUG - Iteration 2: Updating centroids
# 2025-07-10 09:54:57,194 - DEBUG - Iteration 2: Updating labels
# 2025-07-10 09:54:57,194 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,195 - DEBUG - Iteration 3: Checking constraints
# 2025-07-10 09:54:57,204 - DEBUG - Iteration 3: Updating centroids
# 2025-07-10 09:54:57,205 - DEBUG - Iteration 3: Updating labels
# 2025-07-10 09:54:57,205 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,205 - DEBUG - Iteration 4: Checking constraints
# 2025-07-10 09:54:57,214 - DEBUG - Iteration 4: Updating centroids
# 2025-07-10 09:54:57,215 - DEBUG - Iteration 4: Updating labels
# 2025-07-10 09:54:57,215 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,215 - DEBUG - Iteration 5: Checking constraints
# 2025-07-10 09:54:57,224 - DEBUG - Iteration 5: Updating centroids
# 2025-07-10 09:54:57,225 - DEBUG - Iteration 5: Updating labels
# 2025-07-10 09:54:57,225 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,225 - DEBUG - Iteration 6: Checking constraints
# 2025-07-10 09:54:57,234 - DEBUG - Iteration 6: Updating centroids
# 2025-07-10 09:54:57,235 - DEBUG - Iteration 6: Updating labels
# 2025-07-10 09:54:57,235 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,235 - DEBUG - Iteration 7: Checking constraints
# 2025-07-10 09:54:57,245 - DEBUG - Iteration 7: Updating centroids
# 2025-07-10 09:54:57,245 - DEBUG - Iteration 7: Updating labels
# 2025-07-10 09:54:57,246 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,246 - DEBUG - Iteration 8: Checking constraints
# 2025-07-10 09:54:57,255 - DEBUG - Iteration 8: Updating centroids
# 2025-07-10 09:54:57,256 - DEBUG - Iteration 8: Updating labels
# 2025-07-10 09:54:57,256 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,256 - DEBUG - Iteration 9: Checking constraints
# 2025-07-10 09:54:57,264 - DEBUG - Iteration 9: Updating centroids
# 2025-07-10 09:54:57,265 - DEBUG - Iteration 9: Updating labels
# 2025-07-10 09:54:57,265 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,266 - DEBUG - Iteration 10: Checking constraints
# 2025-07-10 09:54:57,274 - DEBUG - Iteration 10: Updating centroids
# 2025-07-10 09:54:57,275 - DEBUG - Iteration 10: Updating labels
# 2025-07-10 09:54:57,275 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,275 - DEBUG - Iteration 11: Checking constraints
# 2025-07-10 09:54:57,284 - DEBUG - Iteration 11: Updating centroids
# 2025-07-10 09:54:57,285 - DEBUG - Iteration 11: Updating labels
# 2025-07-10 09:54:57,285 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,285 - DEBUG - Iteration 12: Checking constraints
# 2025-07-10 09:54:57,294 - DEBUG - Iteration 12: Updating centroids
# 2025-07-10 09:54:57,295 - DEBUG - Iteration 12: Updating labels
# 2025-07-10 09:54:57,295 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,295 - DEBUG - Iteration 13: Checking constraints
# 2025-07-10 09:54:57,304 - DEBUG - Iteration 13: Updating centroids
# 2025-07-10 09:54:57,305 - DEBUG - Iteration 13: Updating labels
# 2025-07-10 09:54:57,305 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,305 - DEBUG - Iteration 14: Checking constraints
# 2025-07-10 09:54:57,314 - DEBUG - Iteration 14: Updating centroids
# 2025-07-10 09:54:57,315 - DEBUG - Iteration 14: Updating labels
# 2025-07-10 09:54:57,315 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,315 - DEBUG - Iteration 15: Checking constraints
# 2025-07-10 09:54:57,334 - DEBUG - Iteration 15: Updating centroids
# 2025-07-10 09:54:57,336 - DEBUG - Iteration 15: Updating labels
# 2025-07-10 09:54:57,336 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,337 - DEBUG - Iteration 16: Checking constraints
# 2025-07-10 09:54:57,348 - DEBUG - Iteration 16: Updating centroids
# 2025-07-10 09:54:57,350 - DEBUG - Iteration 16: Updating labels
# 2025-07-10 09:54:57,350 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,350 - DEBUG - Iteration 17: Checking constraints
# 2025-07-10 09:54:57,361 - DEBUG - Iteration 17: Updating centroids
# 2025-07-10 09:54:57,362 - DEBUG - Iteration 17: Updating labels
# 2025-07-10 09:54:57,363 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,363 - DEBUG - Iteration 18: Checking constraints
# 2025-07-10 09:54:57,374 - DEBUG - Iteration 18: Updating centroids
# 2025-07-10 09:54:57,383 - DEBUG - Iteration 18: Updating labels
# 2025-07-10 09:54:57,384 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,386 - DEBUG - Iteration 19: Checking constraints
# 2025-07-10 09:54:57,398 - DEBUG - Iteration 19: Updating centroids
# 2025-07-10 09:54:57,399 - DEBUG - Iteration 19: Updating labels
# 2025-07-10 09:54:57,399 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,399 - DEBUG - Iteration 20: Checking constraints
# 2025-07-10 09:54:57,409 - DEBUG - Iteration 20: Updating centroids
# 2025-07-10 09:54:57,409 - DEBUG - Iteration 20: Updating labels
# 2025-07-10 09:54:57,410 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,410 - DEBUG - Iteration 21: Checking constraints
# 2025-07-10 09:54:57,419 - DEBUG - Iteration 21: Updating centroids
# 2025-07-10 09:54:57,420 - DEBUG - Iteration 21: Updating labels
# 2025-07-10 09:54:57,420 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,421 - DEBUG - Iteration 22: Checking constraints
# 2025-07-10 09:54:57,430 - DEBUG - Iteration 22: Updating centroids
# 2025-07-10 09:54:57,431 - DEBUG - Iteration 22: Updating labels
# 2025-07-10 09:54:57,431 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,431 - DEBUG - Iteration 23: Checking constraints
# 2025-07-10 09:54:57,441 - DEBUG - Iteration 23: Updating centroids
# 2025-07-10 09:54:57,441 - DEBUG - Iteration 23: Updating labels
# 2025-07-10 09:54:57,442 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,442 - DEBUG - Iteration 24: Checking constraints
# 2025-07-10 09:54:57,450 - DEBUG - Iteration 24: Updating centroids
# 2025-07-10 09:54:57,451 - DEBUG - Iteration 24: Updating labels
# 2025-07-10 09:54:57,451 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,451 - DEBUG - Iteration 25: Checking constraints
# 2025-07-10 09:54:57,461 - DEBUG - Iteration 25: Updating centroids
# 2025-07-10 09:54:57,462 - DEBUG - Iteration 25: Updating labels
# 2025-07-10 09:54:57,462 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,462 - DEBUG - Iteration 26: Checking constraints
# 2025-07-10 09:54:57,472 - DEBUG - Iteration 26: Updating centroids
# 2025-07-10 09:54:57,473 - DEBUG - Iteration 26: Updating labels
# 2025-07-10 09:54:57,473 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,473 - DEBUG - Iteration 27: Checking constraints
# 2025-07-10 09:54:57,482 - DEBUG - Iteration 27: Updating centroids
# 2025-07-10 09:54:57,482 - DEBUG - Iteration 27: Updating labels
# 2025-07-10 09:54:57,483 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,483 - DEBUG - Iteration 28: Checking constraints
# 2025-07-10 09:54:57,492 - DEBUG - Iteration 28: Updating centroids
# 2025-07-10 09:54:57,493 - DEBUG - Iteration 28: Updating labels
# 2025-07-10 09:54:57,493 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,493 - DEBUG - Iteration 29: Checking constraints
# 2025-07-10 09:54:57,502 - DEBUG - Iteration 29: Updating centroids
# 2025-07-10 09:54:57,503 - DEBUG - Iteration 29: Updating labels
# 2025-07-10 09:54:57,503 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,503 - DEBUG - Iteration 30: Checking constraints
# 2025-07-10 09:54:57,537 - DEBUG - Iteration 30: Updating centroids
# 2025-07-10 09:54:57,539 - DEBUG - Iteration 30: Updating labels
# 2025-07-10 09:54:57,539 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,539 - DEBUG - Iteration 31: Checking constraints
# 2025-07-10 09:54:57,553 - DEBUG - Iteration 31: Updating centroids
# 2025-07-10 09:54:57,555 - DEBUG - Iteration 31: Updating labels
# 2025-07-10 09:54:57,555 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,555 - DEBUG - Iteration 32: Checking constraints
# 2025-07-10 09:54:57,564 - DEBUG - Iteration 32: Updating centroids
# 2025-07-10 09:54:57,565 - DEBUG - Iteration 32: Updating labels
# 2025-07-10 09:54:57,565 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,565 - DEBUG - Iteration 33: Checking constraints
# 2025-07-10 09:54:57,574 - DEBUG - Iteration 33: Updating centroids
# 2025-07-10 09:54:57,575 - DEBUG - Iteration 33: Updating labels
# 2025-07-10 09:54:57,575 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,575 - DEBUG - Iteration 34: Checking constraints
# 2025-07-10 09:54:57,584 - DEBUG - Iteration 34: Updating centroids
# 2025-07-10 09:54:57,584 - DEBUG - Iteration 34: Updating labels
# 2025-07-10 09:54:57,585 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,585 - DEBUG - Iteration 35: Checking constraints
# 2025-07-10 09:54:57,594 - DEBUG - Iteration 35: Updating centroids
# 2025-07-10 09:54:57,595 - DEBUG - Iteration 35: Updating labels
# 2025-07-10 09:54:57,595 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,595 - DEBUG - Iteration 36: Checking constraints
# 2025-07-10 09:54:57,605 - DEBUG - Iteration 36: Updating centroids
# 2025-07-10 09:54:57,606 - DEBUG - Iteration 36: Updating labels
# 2025-07-10 09:54:57,606 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,606 - DEBUG - Iteration 37: Checking constraints
# 2025-07-10 09:54:57,615 - DEBUG - Iteration 37: Updating centroids
# 2025-07-10 09:54:57,617 - DEBUG - Iteration 37: Updating labels
# 2025-07-10 09:54:57,617 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,618 - DEBUG - Iteration 38: Checking constraints
# 2025-07-10 09:54:57,627 - DEBUG - Iteration 38: Updating centroids
# 2025-07-10 09:54:57,628 - DEBUG - Iteration 38: Updating labels
# 2025-07-10 09:54:57,629 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,629 - DEBUG - Iteration 39: Checking constraints
# 2025-07-10 09:54:57,638 - DEBUG - Iteration 39: Updating centroids
# 2025-07-10 09:54:57,639 - DEBUG - Iteration 39: Updating labels
# 2025-07-10 09:54:57,639 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,639 - DEBUG - Iteration 40: Checking constraints
# 2025-07-10 09:54:57,648 - DEBUG - Iteration 40: Updating centroids
# 2025-07-10 09:54:57,648 - DEBUG - Iteration 40: Updating labels
# 2025-07-10 09:54:57,649 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,649 - DEBUG - Iteration 41: Checking constraints
# 2025-07-10 09:54:57,658 - DEBUG - Iteration 41: Updating centroids
# 2025-07-10 09:54:57,659 - DEBUG - Iteration 41: Updating labels
# 2025-07-10 09:54:57,659 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,659 - DEBUG - Iteration 42: Checking constraints
# 2025-07-10 09:54:57,668 - DEBUG - Iteration 42: Updating centroids
# 2025-07-10 09:54:57,669 - DEBUG - Iteration 42: Updating labels
# 2025-07-10 09:54:57,669 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,670 - DEBUG - Iteration 43: Checking constraints
# 2025-07-10 09:54:57,679 - DEBUG - Iteration 43: Updating centroids
# 2025-07-10 09:54:57,679 - DEBUG - Iteration 43: Updating labels
# 2025-07-10 09:54:57,680 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,680 - DEBUG - Iteration 44: Checking constraints
# 2025-07-10 09:54:57,689 - DEBUG - Iteration 44: Updating centroids
# 2025-07-10 09:54:57,690 - DEBUG - Iteration 44: Updating labels
# 2025-07-10 09:54:57,690 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,690 - DEBUG - Iteration 45: Checking constraints
# 2025-07-10 09:54:57,699 - DEBUG - Iteration 45: Updating centroids
# 2025-07-10 09:54:57,700 - DEBUG - Iteration 45: Updating labels
# 2025-07-10 09:54:57,700 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,700 - DEBUG - Iteration 46: Checking constraints
# 2025-07-10 09:54:57,709 - DEBUG - Iteration 46: Updating centroids
# 2025-07-10 09:54:57,710 - DEBUG - Iteration 46: Updating labels
# 2025-07-10 09:54:57,711 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,711 - DEBUG - Iteration 47: Checking constraints
# 2025-07-10 09:54:57,720 - DEBUG - Iteration 47: Updating centroids
# 2025-07-10 09:54:57,721 - DEBUG - Iteration 47: Updating labels
# 2025-07-10 09:54:57,721 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,721 - DEBUG - Iteration 48: Checking constraints
# 2025-07-10 09:54:57,729 - DEBUG - Iteration 48: Updating centroids
# 2025-07-10 09:54:57,730 - DEBUG - Iteration 48: Updating labels
# 2025-07-10 09:54:57,730 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,731 - DEBUG - Iteration 49: Checking constraints
# 2025-07-10 09:54:57,740 - DEBUG - Iteration 49: Updating centroids
# 2025-07-10 09:54:57,741 - DEBUG - Iteration 49: Updating labels
# 2025-07-10 09:54:57,741 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,742 - DEBUG - Iteration 50: Checking constraints
# 2025-07-10 09:54:57,750 - DEBUG - Iteration 50: Updating centroids
# 2025-07-10 09:54:57,751 - DEBUG - Iteration 50: Updating labels
# 2025-07-10 09:54:57,751 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,751 - DEBUG - Iteration 51: Checking constraints
# 2025-07-10 09:54:57,761 - DEBUG - Iteration 51: Updating centroids
# 2025-07-10 09:54:57,762 - DEBUG - Iteration 51: Updating labels
# 2025-07-10 09:54:57,762 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,762 - DEBUG - Iteration 52: Checking constraints
# 2025-07-10 09:54:57,771 - DEBUG - Iteration 52: Updating centroids
# 2025-07-10 09:54:57,772 - DEBUG - Iteration 52: Updating labels
# 2025-07-10 09:54:57,772 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,773 - DEBUG - Iteration 53: Checking constraints
# 2025-07-10 09:54:57,781 - DEBUG - Iteration 53: Updating centroids
# 2025-07-10 09:54:57,782 - DEBUG - Iteration 53: Updating labels
# 2025-07-10 09:54:57,782 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,783 - DEBUG - Iteration 54: Checking constraints
# 2025-07-10 09:54:57,792 - DEBUG - Iteration 54: Updating centroids
# 2025-07-10 09:54:57,793 - DEBUG - Iteration 54: Updating labels
# 2025-07-10 09:54:57,793 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,793 - DEBUG - Iteration 55: Checking constraints
# 2025-07-10 09:54:57,802 - DEBUG - Iteration 55: Updating centroids
# 2025-07-10 09:54:57,803 - DEBUG - Iteration 55: Updating labels
# 2025-07-10 09:54:57,803 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,804 - DEBUG - Iteration 56: Checking constraints
# 2025-07-10 09:54:57,812 - DEBUG - Iteration 56: Updating centroids
# 2025-07-10 09:54:57,813 - DEBUG - Iteration 56: Updating labels
# 2025-07-10 09:54:57,813 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,814 - DEBUG - Iteration 57: Checking constraints
# 2025-07-10 09:54:57,848 - DEBUG - Iteration 57: Updating centroids
# 2025-07-10 09:54:57,851 - DEBUG - Iteration 57: Updating labels
# 2025-07-10 09:54:57,851 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,852 - DEBUG - Iteration 58: Checking constraints
# 2025-07-10 09:54:57,865 - DEBUG - Iteration 58: Updating centroids
# 2025-07-10 09:54:57,866 - DEBUG - Iteration 58: Updating labels
# 2025-07-10 09:54:57,866 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,866 - DEBUG - Iteration 59: Checking constraints
# 2025-07-10 09:54:57,875 - DEBUG - Iteration 59: Updating centroids
# 2025-07-10 09:54:57,876 - DEBUG - Iteration 59: Updating labels
# 2025-07-10 09:54:57,876 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,877 - DEBUG - Iteration 60: Checking constraints
# 2025-07-10 09:54:57,886 - DEBUG - Iteration 60: Updating centroids
# 2025-07-10 09:54:57,887 - DEBUG - Iteration 60: Updating labels
# 2025-07-10 09:54:57,887 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,888 - DEBUG - Iteration 61: Checking constraints
# 2025-07-10 09:54:57,896 - DEBUG - Iteration 61: Updating centroids
# 2025-07-10 09:54:57,897 - DEBUG - Iteration 61: Updating labels
# 2025-07-10 09:54:57,897 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,897 - DEBUG - Iteration 62: Checking constraints
# 2025-07-10 09:54:57,907 - DEBUG - Iteration 62: Updating centroids
# 2025-07-10 09:54:57,908 - DEBUG - Iteration 62: Updating labels
# 2025-07-10 09:54:57,908 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,908 - DEBUG - Iteration 63: Checking constraints
# 2025-07-10 09:54:57,917 - DEBUG - Iteration 63: Updating centroids
# 2025-07-10 09:54:57,919 - DEBUG - Iteration 63: Updating labels
# 2025-07-10 09:54:57,919 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,919 - DEBUG - Iteration 64: Checking constraints
# 2025-07-10 09:54:57,929 - DEBUG - Iteration 64: Updating centroids
# 2025-07-10 09:54:57,929 - DEBUG - Iteration 64: Updating labels
# 2025-07-10 09:54:57,930 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,930 - DEBUG - Iteration 65: Checking constraints
# 2025-07-10 09:54:57,940 - DEBUG - Iteration 65: Updating centroids
# 2025-07-10 09:54:57,941 - DEBUG - Iteration 65: Updating labels
# 2025-07-10 09:54:57,941 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,941 - DEBUG - Iteration 66: Checking constraints
# 2025-07-10 09:54:57,950 - DEBUG - Iteration 66: Updating centroids
# 2025-07-10 09:54:57,951 - DEBUG - Iteration 66: Updating labels
# 2025-07-10 09:54:57,951 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,952 - DEBUG - Iteration 67: Checking constraints
# 2025-07-10 09:54:57,962 - DEBUG - Iteration 67: Updating centroids
# 2025-07-10 09:54:57,962 - DEBUG - Iteration 67: Updating labels
# 2025-07-10 09:54:57,963 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,963 - DEBUG - Iteration 68: Checking constraints
# 2025-07-10 09:54:57,973 - DEBUG - Iteration 68: Updating centroids
# 2025-07-10 09:54:57,973 - DEBUG - Iteration 68: Updating labels
# 2025-07-10 09:54:57,974 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,974 - DEBUG - Iteration 69: Checking constraints
# 2025-07-10 09:54:57,983 - DEBUG - Iteration 69: Updating centroids
# 2025-07-10 09:54:57,984 - DEBUG - Iteration 69: Updating labels
# 2025-07-10 09:54:57,984 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,984 - DEBUG - Iteration 70: Checking constraints
# 2025-07-10 09:54:57,995 - DEBUG - Iteration 70: Updating centroids
# 2025-07-10 09:54:57,995 - DEBUG - Iteration 70: Updating labels
# 2025-07-10 09:54:57,996 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:57,996 - DEBUG - Iteration 71: Checking constraints
# 2025-07-10 09:54:58,006 - DEBUG - Iteration 71: Updating centroids
# 2025-07-10 09:54:58,007 - DEBUG - Iteration 71: Updating labels
# 2025-07-10 09:54:58,007 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,007 - DEBUG - Iteration 72: Checking constraints
# 2025-07-10 09:54:58,016 - DEBUG - Iteration 72: Updating centroids
# 2025-07-10 09:54:58,017 - DEBUG - Iteration 72: Updating labels
# 2025-07-10 09:54:58,017 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,017 - DEBUG - Iteration 73: Checking constraints
# 2025-07-10 09:54:58,027 - DEBUG - Iteration 73: Updating centroids
# 2025-07-10 09:54:58,028 - DEBUG - Iteration 73: Updating labels
# 2025-07-10 09:54:58,028 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,028 - DEBUG - Iteration 74: Checking constraints
# 2025-07-10 09:54:58,038 - DEBUG - Iteration 74: Updating centroids
# 2025-07-10 09:54:58,039 - DEBUG - Iteration 74: Updating labels
# 2025-07-10 09:54:58,039 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,040 - DEBUG - Iteration 75: Checking constraints
# 2025-07-10 09:54:58,048 - DEBUG - Iteration 75: Updating centroids
# 2025-07-10 09:54:58,049 - DEBUG - Iteration 75: Updating labels
# 2025-07-10 09:54:58,050 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,050 - DEBUG - Iteration 76: Checking constraints
# 2025-07-10 09:54:58,059 - DEBUG - Iteration 76: Updating centroids
# 2025-07-10 09:54:58,060 - DEBUG - Iteration 76: Updating labels
# 2025-07-10 09:54:58,060 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,060 - DEBUG - Iteration 77: Checking constraints
# 2025-07-10 09:54:58,071 - DEBUG - Iteration 77: Updating centroids
# 2025-07-10 09:54:58,071 - DEBUG - Iteration 77: Updating labels
# 2025-07-10 09:54:58,072 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,072 - DEBUG - Iteration 78: Checking constraints
# 2025-07-10 09:54:58,081 - DEBUG - Iteration 78: Updating centroids
# 2025-07-10 09:54:58,082 - DEBUG - Iteration 78: Updating labels
# 2025-07-10 09:54:58,082 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,083 - DEBUG - Iteration 79: Checking constraints
# 2025-07-10 09:54:58,093 - DEBUG - Iteration 79: Updating centroids
# 2025-07-10 09:54:58,093 - DEBUG - Iteration 79: Updating labels
# 2025-07-10 09:54:58,094 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,094 - DEBUG - Iteration 80: Checking constraints
# 2025-07-10 09:54:58,104 - DEBUG - Iteration 80: Updating centroids
# 2025-07-10 09:54:58,105 - DEBUG - Iteration 80: Updating labels
# 2025-07-10 09:54:58,105 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,105 - DEBUG - Iteration 81: Checking constraints
# 2025-07-10 09:54:58,114 - DEBUG - Iteration 81: Updating centroids
# 2025-07-10 09:54:58,115 - DEBUG - Iteration 81: Updating labels
# 2025-07-10 09:54:58,115 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,115 - DEBUG - Iteration 82: Checking constraints
# 2025-07-10 09:54:58,140 - DEBUG - Iteration 82: Updating centroids
# 2025-07-10 09:54:58,148 - DEBUG - Iteration 82: Updating labels
# 2025-07-10 09:54:58,149 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,149 - DEBUG - Iteration 83: Checking constraints
# 2025-07-10 09:54:58,165 - DEBUG - Iteration 83: Updating centroids
# 2025-07-10 09:54:58,166 - DEBUG - Iteration 83: Updating labels
# 2025-07-10 09:54:58,166 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,166 - DEBUG - Iteration 84: Checking constraints
# 2025-07-10 09:54:58,175 - DEBUG - Iteration 84: Updating centroids
# 2025-07-10 09:54:58,176 - DEBUG - Iteration 84: Updating labels
# 2025-07-10 09:54:58,176 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,176 - DEBUG - Iteration 85: Checking constraints
# 2025-07-10 09:54:58,185 - DEBUG - Iteration 85: Updating centroids
# 2025-07-10 09:54:58,186 - DEBUG - Iteration 85: Updating labels
# 2025-07-10 09:54:58,187 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,187 - DEBUG - Iteration 86: Checking constraints
# 2025-07-10 09:54:58,195 - DEBUG - Iteration 86: Updating centroids
# 2025-07-10 09:54:58,196 - DEBUG - Iteration 86: Updating labels
# 2025-07-10 09:54:58,197 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,197 - DEBUG - Iteration 87: Checking constraints
# 2025-07-10 09:54:58,215 - DEBUG - Iteration 87: Updating centroids
# 2025-07-10 09:54:58,216 - DEBUG - Iteration 87: Updating labels
# 2025-07-10 09:54:58,217 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,217 - DEBUG - Iteration 88: Checking constraints
# 2025-07-10 09:54:58,225 - DEBUG - Iteration 88: Updating centroids
# 2025-07-10 09:54:58,226 - DEBUG - Iteration 88: Updating labels
# 2025-07-10 09:54:58,226 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,226 - DEBUG - Iteration 89: Checking constraints
# 2025-07-10 09:54:58,235 - DEBUG - Iteration 89: Updating centroids
# 2025-07-10 09:54:58,236 - DEBUG - Iteration 89: Updating labels
# 2025-07-10 09:54:58,236 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,236 - DEBUG - Iteration 90: Checking constraints
# 2025-07-10 09:54:58,246 - DEBUG - Iteration 90: Updating centroids
# 2025-07-10 09:54:58,247 - DEBUG - Iteration 90: Updating labels
# 2025-07-10 09:54:58,247 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,247 - DEBUG - Iteration 91: Checking constraints
# 2025-07-10 09:54:58,256 - DEBUG - Iteration 91: Updating centroids
# 2025-07-10 09:54:58,257 - DEBUG - Iteration 91: Updating labels
# 2025-07-10 09:54:58,257 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,257 - DEBUG - Iteration 92: Checking constraints
# 2025-07-10 09:54:58,266 - DEBUG - Iteration 92: Updating centroids
# 2025-07-10 09:54:58,267 - DEBUG - Iteration 92: Updating labels
# 2025-07-10 09:54:58,267 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,267 - DEBUG - Iteration 93: Checking constraints
# 2025-07-10 09:54:58,277 - DEBUG - Iteration 93: Updating centroids
# 2025-07-10 09:54:58,278 - DEBUG - Iteration 93: Updating labels
# 2025-07-10 09:54:58,278 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,278 - DEBUG - Iteration 94: Checking constraints
# 2025-07-10 09:54:58,287 - DEBUG - Iteration 94: Updating centroids
# 2025-07-10 09:54:58,288 - DEBUG - Iteration 94: Updating labels
# 2025-07-10 09:54:58,288 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,289 - DEBUG - Iteration 95: Checking constraints
# 2025-07-10 09:54:58,297 - DEBUG - Iteration 95: Updating centroids
# 2025-07-10 09:54:58,298 - DEBUG - Iteration 95: Updating labels
# 2025-07-10 09:54:58,298 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,299 - DEBUG - Iteration 96: Checking constraints
# 2025-07-10 09:54:58,308 - DEBUG - Iteration 96: Updating centroids
# 2025-07-10 09:54:58,309 - DEBUG - Iteration 96: Updating labels
# 2025-07-10 09:54:58,309 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,309 - DEBUG - Iteration 97: Checking constraints
# 2025-07-10 09:54:58,318 - DEBUG - Iteration 97: Updating centroids
# 2025-07-10 09:54:58,319 - DEBUG - Iteration 97: Updating labels
# 2025-07-10 09:54:58,319 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,319 - DEBUG - Iteration 98: Checking constraints
# 2025-07-10 09:54:58,328 - DEBUG - Iteration 98: Updating centroids
# 2025-07-10 09:54:58,329 - DEBUG - Iteration 98: Updating labels
# 2025-07-10 09:54:58,329 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,330 - DEBUG - Iteration 99: Checking constraints
# 2025-07-10 09:54:58,339 - DEBUG - Iteration 99: Updating centroids
# 2025-07-10 09:54:58,340 - DEBUG - Iteration 99: Updating labels
# 2025-07-10 09:54:58,340 - DEBUG - Delta is None, convergence cannot be checked.
# 2025-07-10 09:54:58,340 - DEBUG - Iteration 100: Checking constraints
# 2025-07-10 09:54:58,349 - DEBUG - Iteration 100: Updating centroids
# 2025-07-10 09:54:58,350 - DEBUG - Iteration 100: Updating labels
# 2025-07-10 09:54:58,350 - DEBUG - Delta is None, convergence cannot be checked.
# array([[-1.8069941 ,  7.68326852],
#        [-1.7700408 ,  8.91611213],
#        [-1.97132925,  8.52367237],
#        [-1.78118179,  8.74954314],
#        [-1.79131443,  8.81295896],
#        [-1.86257907,  8.88580563],
#        [-1.81130505,  8.66424649],
#        [-1.80950166,  8.92751759],
#        [-1.82984396,  8.82734938],
#        [-1.79108163,  8.8324335 ]])

# %%
mtx = np.random.randint(-1, 2, size = (10, 10))
mtx = mtx - np.diag(np.diag(mtx))  # Remove diagonal elements
for i, j in np.argwhere(mtx > 0):
    print(f"{i} --- {j}")
# Out:
# 0 --- 1
# 0 --- 2
# 0 --- 3
# 0 --- 5
# 0 --- 6
# 0 --- 8
# 1 --- 6
# 1 --- 9
# 2 --- 1
# 2 --- 3
# 2 --- 4
# 2 --- 8
# 3 --- 4
# 3 --- 5
# 3 --- 7
# 4 --- 3
# 4 --- 7
# 5 --- 7
# 6 --- 2
# 6 --- 3
# 6 --- 4
# 6 --- 5
# 6 --- 8
# 8 --- 0
# 8 --- 6
# 9 --- 0
# 9 --- 3

# %%
centroids = np.array([np.mean(X[y == label], axis = 0) for label in np.unique(y)])

# %%
centroids
# Out:
# array([[-2.74838844,  9.00706414],
#        [ 4.57178916,  1.95986261],
#        [-6.93249308, -6.69717547],
#        [-8.83786767,  7.54111511],
#        [ 2.33040889,  3.9558622 ],
#        [-9.42239376,  9.35999659],
#        [ 6.63614325, -5.55485231],
#        [-6.382179  , -6.50569821],
#        [-4.13139815,  0.20678414],
#        [-1.24251742, -4.14405026]])
