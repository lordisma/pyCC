# %%
import numpy as np
from sklearn.datasets import load_iris
import plotly.express as px

import logging
import sys

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(sys.stdout)
    ]
)

COLORS = [
    "#f7dc6f",
    "#82e0aa",
    "#f1948a",
    "#499cef",
    "#f5b041",
    "#a569bd",
    "#e74c3c",
    "#2ecc71",
    "#3498db",
    "#e67e22",
    "#9b59b6",
    "#1abc9c",
    "#34495e",
    "#d35400",
    "#c0392b",
    "#16a085",
    "#2980b9",
    "#8e44ad",
]

def plot_dataframe(df, label, title=''):
    fig = px.scatter(
        x=df[:, 0],
        y=df[:, 1],
        color=[COLORS[i] for i in label],
        title=title,
    )
    fig.update_traces(marker=dict(size=5, symbol='circle', opacity = 0.6))

    return fig

def plot_centroid(fig, centroid, colors = ['#a569bd'], marker_size=10, symbol = 'star', name = 'Centroid'):
    fig.add_scatter(
        x=[centroid[0]],
        y=[centroid[1]],
        mode='markers',
        marker=dict(
            size = marker_size,
            color = colors[0],
            symbol = symbol,
        ),
        name=name
    )
    return fig

def create_constraints(labels, probability=0.01, seed=0):
    n_points = len(labels)
    constraints = np.zeros((n_points, n_points), dtype=int)
    state = np.random.RandomState(seed=seed)
    for i in range(n_points):
        for j in range(i +1, n_points):
            if state.rand() < probability:
                if labels[i] == labels[j]:
                    constraints[i, j] = 1
                    constraints[j, i] = 1
                elif labels[i] != labels[j]:
                    constraints[i, j] = -1
                    constraints[j, i] = -1
    return constraints

def draw_cl_constraints(fig, constraints, points):
    n_points = len(points)
    for i in range(n_points):
        for j in range(i + 1, n_points):
            if constraints[i, j] < 0:
                fig.add_scatter(
                    x=[points[i, 0], points[j, 0]],
                    y=[points[i, 1], points[j, 1]],
                    mode='lines',
                    line=dict(color='red', width=0.5, dash='dash'),
                )
    return fig

def draw_ml_constraints(fig, constraints, points):
    n_points = len(points)
    for i in range(n_points):
        for j in range(i + 1, n_points):
            if constraints[i, j] > 0:
                fig.add_scatter(
                    x=[points[i, 0], points[j, 0]],
                    y=[points[i, 1], points[j, 1]],
                    mode='lines',
                    line=dict(color='green', width=0.5),
                )
    return fig

# %%
X, y = load_iris(return_X_y=True)

test = np.random.randint(0, X.shape[0], size=15)

validation = X[test]
y_validation = y[test]

X = np.delete(X, test, axis=0)
y = np.delete(y, test, axis=0)

constraints = create_constraints(y, probability=0.01, seed=42)

# %%
from clustlib.gac.brkga import BRKGA
brkga = BRKGA(
    n_clusters=3,
    constraints=constraints,
    max_iter=10000,
    tol=1e-10,
)
brkga.fit(X)

centroids = brkga.centroids
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       1 from clustlib.gac.brkga import BRKGA
#       2 brkga = BRKGA(
#       3     n_clusters=3,
#       4     constraints=constraints,
#       5     max_iter=10000,
#       6     tol=1e-10,
#       7 )
# ----> 8 brkga.fit(X)
#      10 centroids = brkga.centroids
#
# File ~/Documents/Projects/clustlib/clustlib/model.py:81, in BaseEstimator.fit(self, dataset, labels)
#      78 else:
#      79     self._labels = np.copy(labels)
# ---> 81 return self._fit()
#
# File ~/Documents/Projects/clustlib/clustlib/gac/brkga.py:105, in BRKGA._fit(self)
#     103 iteration = 0
#     104 while not self.stop_criteria(iteration):
# --> 105     self.update()
#     106     iteration += 1
#     108 return self
#
# File ~/Documents/Projects/clustlib/clustlib/model.py:134, in BaseEstimator.update(self)
#     126 """Update the centroids of the clusters.
#     127
#     128 This method calls the `_update` method to update the centroids of the clusters.
#    (...)    131 the centroids and is used to determine when the algorithm has converged.
#     132 """
#     133 aux = np.copy(self.centroids)
# --> 134 self._update()
#     135 self._delta = self.calculte_delta(aux)
#
# File ~/Documents/Projects/clustlib/clustlib/gac/brkga.py:72, in BRKGA._update(self)
#      69 else:
#      70     self.population[self._num_elite :, :] = mutants
# ---> 72 self.calculate_fitness()
#      73 self._labels = self.decode_solution(self.population[0, :])
#      74 self.centroids = self.get_centroids(self._labels)
#
# File ~/Documents/Projects/clustlib/clustlib/gac/_base.py:37, in GeneticClustering.calculate_fitness(self)
#      35 def calculate_fitness(self):
#      36     self._population_fitness = np.array(
# ---> 37         [self.fitness(solution) for solution in self.population]
#      38     )
#      39     self.population = self.population[np.argsort(self._population_fitness), :]
#      40     self._population_fitness = np.sort(self._population_fitness)
#
# File ~/Documents/Projects/clustlib/clustlib/gac/_base.py:28, in GeneticClustering.fitness(self, solution)
#      26 labels = self.decode_solution(solution)
#      27 total_distance = self.distance_to_cluster(labels)
# ---> 28 infeasability = self.infeseability(labels)
#      30 fitness = total_distance + infeasability
#      31 if math.isnan(fitness):
#
# File ~/Documents/Projects/clustlib/clustlib/gac/_base.py:60, in GeneticClustering.infeseability(self, labels)
#      58 for idx, cluster in enumerate(labels):
#      59     ml = np.argwhere(self.constraints[idx] > 0).flatten()
# ---> 60     linked = np.argwhere(labels == cluster).flatten()
#      62     ml_infeasability = ml.shape[0] - np.sum(np.isin(linked, ml))
#      64     cl = np.argwhere(self.constraints[idx] < 0).flatten().sort()
#
# File ~/Library/Caches/pypoetry/virtualenvs/clustlib-5JQ_NFw--py3.13/lib/python3.13/site-packages/numpy/_core/numeric.py:673, in argwhere(a)
#     671     # then remove the added dimension
#     672     return argwhere(a)[:, :0]
# --> 673 return transpose(nonzero(a))
#
# File ~/Library/Caches/pypoetry/virtualenvs/clustlib-5JQ_NFw--py3.13/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:629, in transpose(a, axes)
#     625 def _transpose_dispatcher(a, axes=None):
#     626     return (a,)
# --> 629 @array_function_dispatch(_transpose_dispatcher)
#     630 def transpose(a, axes=None):
#     631     """
#     632     Returns an array with axes transposed.
#     633
#    (...)    700
#     701     """
#     702     return _wrapfunc(a, 'transpose', axes)
#
# KeyboardInterrupt:

# %%
predicted = brkga.predict(validation)

# %%
fig = plot_dataframe(validation[:, :2], title='Blobs Dataset', label=y_validation)
for i, centroid in enumerate(centroids):
    fig = plot_centroid(fig, centroid, colors=["#e67e22"], marker_size=10, symbol='star', name=f'Centroid {i+1}')
fig.update_layout(showlegend=False, title='Setosa vs Versicolor')
fig.show()

# %%
fig = plot_dataframe(validation[:, 1:3], title='Blobs Dataset', label=y_validation)
for i, centroid in enumerate(centroids):
    fig = plot_centroid(fig, centroid[1:3], colors=["#e67e22"], marker_size=10, symbol='star', name=f'Centroid {i+1}')
fig.update_layout(showlegend=False, title='Versicolor vs Virginica')
fig.show()

# %%
fig = plot_dataframe(validation[:,[0, 2]], title='Blobs Dataset', label=y_validation)
for i, centroid in enumerate(centroids):
    fig = plot_centroid(fig, centroid[[0,2]], colors=["#e67e22"], marker_size=10, symbol='star', name=f'Centroid {i+1}')
fig.update_layout(showlegend=False, title='Setosa vs Virginica')
fig.show()
